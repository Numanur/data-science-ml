# %% [markdown]
# <a href="https://colab.research.google.com/github/Numanur/data-science-ml/blob/main/heart_desease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/Colab Datasets/heart-disease.csv')
print(df.head(10))
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
df.to_excel('/content/drive/MyDrive/Colab Datasets/heart-disease.xlsx', sheet_name="heart-disease", index=False)

# %% [markdown]
# df.info()

# %%
#only specific column
ages = df["sex"]

# %%
#only specific row
print(df.iloc[3])

#filtering
above_30 = df[df['age']>30]
print(above_30.head())

#only male or female
males = df[df['sex'] == 1]
print(males.head())

#specific row column
fem = df.loc[df['age']>30,['sex','age',"chol"]]
print(fem.head())

#slicing the rows, columns
print(df.iloc[10:25, 2:5])
# Out:
# age          56.0
# sex           1.0
# cp            1.0
# trestbps    120.0
# chol        236.0
# fbs           0.0
# restecg       1.0
# thalach     178.0
# exang         0.0
# oldpeak       0.8
# slope         2.0
# ca            0.0
# thal          2.0
# target        1.0
# Name: 3, dtype: float64
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# ...

# %%
#start plotting those data

df.plot()
plt.title("Heart Disease")
plt.show()

# %%
df_sorted =  df.sort_values('age', ascending=False)
plt.title("Age vs Cholesterol")

df_sorted.plot(x="age", y="chol")
df_sorted.plot.scatter(x='age', y='chol')
plt.show()
