# %% [markdown]
# <a href="https://colab.research.google.com/github/Numanur/data-science-ml/blob/main/seaborn_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2020", periods=1000))
data.plot()
ds = data.cumsum()
ds.plot()
# Out:
# <Axes: >

# %% [markdown]
# # **The Object Oriented Method**

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Datasets/heart-disease.csv")
df.plot(kind="scatter",
        x="age",
        y="chol")
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
fix, ax = plt.subplots(figsize=(10, 5))
df.plot(kind="scatter", x= "age", y="chol", ax=ax)
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
fix, ax = plt.subplots(figsize=(10,6))
age_50 = df[df["age"]> 50]

scatter = ax.scatter(x=age_50["age"], y=age_50["chol"], c=age_50["target"])
ax.set(title="Age vs Chol", xlabel="Age", ylabel="Cholesterol")
ax.legend(*scatter.legend_elements(), title="Target")
